# %%
import asyncio
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(model='gemini-2.0-flash')

# %%
import time
def ask(question):
    return model.invoke(question).content

async def main():
    questions = [
        "What is AI?",
        "Explain quantum computing.",
        "Why is the sky blue?",
        "How does a rocket work?",
        "Define reinforcement learning."
    ]

    # wrap each blocking ask() call in to_thread
    tasks = [asyncio.to_thread(ask, q) for q in questions]

    # run them all concurrently
    start = time.time()

    responses = await asyncio.gather(*tasks)
    end= time.time()
    
    print(f"\nTime taken: {end - start} seconds")
    for q, r in zip(questions, responses):
        print("\nQ:", q)
        print("A:", r)

    

await main()
# Out:
# Time taken: 10.963785171508789 seconds
#
# Q: What is AI?
# A: AI, or Artificial Intelligence, is a broad field of computer science that aims to create machines that can perform tasks that typically require human intelligence. Think of it as making computers "smart" enough to do things like understand language, recognize images, solve problems, and make decisions.
#
# Here's a breakdown of key aspects:
#
# *   **Mimicking Human Intelligence:** AI systems are designed to simulate human cognitive functions.
# *   **Learning and Adaptation:** Many AI systems can learn from data and improve their performance over time without being explicitly programmed for every situation.
# *   **Problem Solving:** AI is used to tackle complex problems in various domains, from medicine to finance.
# *   **Automation:** AI can automate repetitive tasks, freeing up humans for more creative and strategic work.
#
# **Different Types of AI:**
#
# *   **Narrow or Weak AI:** This type of AI is designed to perform a specific task. Examples include spam filters, recommendation systems, and voice assistants like Siri or Alexa. This is the most common type of AI we see today.
# *   **General or Strong AI:** This is a hypothetical type of AI that possesses human-level intelligence and can perform any intellectual task that a human being can.  Strong AI does not currently exist.
# *   **Super AI:** This is another hypothetical type of AI that would surpass human intelligence in all aspects, including creativity, problem-solving, and general wisdom. This is largely theoretical and often explored in science fiction.
#
# **How AI Works (Simplified):**
#
# *   **Data:** AI systems need data to learn. This data can be in various forms, like text, images, audio, or numbers.
# *   **Algorithms:** Algorithms are sets of instructions that tell the AI system how to process the data and make decisions.
# *   **Machine Learning:** This is a key technique where AI systems learn from data without being explicitly programmed.  There are different types of machine learning:
#     *   **Supervised Learning:**  The AI is trained on labeled data (e.g., images labeled as "cat" or "dog").
#     *   **Unsupervised Learning:**  The AI finds patterns in unlabeled data (e.g., grouping customers based on their purchase history).
#     *   **Reinforcement Learning:** The AI learns through trial and error, receiving rewards for correct actions and penalties for incorrect ones (e.g., training a robot to walk).
# *   **Neural Networks:** These are complex algorithms inspired by the structure of the human brain, used for tasks like image recognition and natural language processing.
#
# **Examples of AI in Action:**
#
# *   **Self-driving cars:**  Use AI to perceive their surroundings and make driving decisions.
# *   **Medical diagnosis:**  AI can analyze medical images and patient data to assist doctors in diagnosing diseases.
# *   **Fraud detection:**  AI algorithms can identify fraudulent transactions in real-time.
# *   **Customer service chatbots:**  AI-powered chatbots can answer customer questions and resolve issues.
# *   **Personalized recommendations:**  AI algorithms suggest products, movies, or music based on your preferences.
#
# **In Summary:**
#
# AI is a rapidly evolving field with the potential to transform many aspects of our lives. It involves creating intelligent machines that can learn, solve problems, and automate tasks. While strong AI remains a distant goal, narrow AI is already having a significant impact on various industries and our daily routines.
#
# Q: Explain quantum computing.
# A: Okay, let's break down quantum computing in a way that's (hopefully!) understandable. It's a complex topic, but we can get the core ideas across.
#
# **What is Quantum Computing? In a Nutshell**
#
# Quantum computing is a new type of computing that leverages the principles of quantum mechanics to solve problems that are too complex for traditional computers.  Think of it as using the bizarre and powerful rules of the quantum world to perform calculations in fundamentally different ways.
#
# **Why Do We Need Quantum Computing?**
#
# Classical computers (the ones we use every day) store and process information as bits, which can be either 0 or 1.  This works great for many things, but it hits a wall when dealing with certain types of problems, especially those involving:
#
# *   **Complex Simulations:**  Like simulating molecular interactions for drug discovery, designing new materials, or predicting weather patterns with extreme accuracy.
# *   **Optimization Problems:**  Finding the best solution from a vast number of possibilities, such as optimizing logistics routes, financial trading strategies, or machine learning models.
# *   **Cryptography:**  Breaking modern encryption algorithms and developing new, quantum-resistant ones.
#
# These problems become exponentially harder for classical computers as the size of the problem increases.  Quantum computers offer the *potential* to solve these problems much more efficiently.
#
# **Key Concepts of Quantum Computing:**
#
# Here are the core ideas you need to understand:
#
# 1.  **Qubits (Quantum Bits):**
#
#     *   **Classical Bits:**  A classical bit is like a switch that is either ON (1) or OFF (0).  It can only be in one state at a time.
#     *   **Qubits:**  A qubit is the quantum equivalent of a bit.  Instead of being just 0 or 1, a qubit can exist in a *superposition* of both states *simultaneously*.  Think of it like a dimmer switch that can be anywhere between ON and OFF at the same time.
#     *   **Superposition:**  This is the magic.  A qubit can be in a combination of 0 and 1 until it's measured. The probability of it collapsing to 0 or 1 is determined by its "quantum state."
#     *   **Representation:**  Qubits are often represented using mathematical notation involving complex numbers.  Don't worry too much about the math; just understand that these numbers describe the probabilities of the qubit collapsing to 0 or 1 when measured.
#
# 2.  **Entanglement:**
#
#     *   This is another mind-bending quantum phenomenon.  When two or more qubits are entangled, their fates are linked together, no matter how far apart they are.
#     *   **Correlation:**  If you measure the state of one entangled qubit, you instantly know the state of the other, even if they are light-years away.
#     *   **Usefulness:**  Entanglement allows quantum computers to perform certain calculations in parallel and achieve exponential speedups.  It's crucial for many quantum algorithms.
#
# 3.  **Quantum Gates:**
#
#     *   Just like classical computers use logic gates (AND, OR, NOT) to manipulate bits, quantum computers use *quantum gates* to manipulate qubits.
#     *   **Unitary Transformations:** Quantum gates are represented by unitary matrices, which are mathematical operations that preserve the quantum state.
#     *   **Examples:**  Common quantum gates include the Hadamard gate (creates superposition), the CNOT gate (creates entanglement), and various rotation gates.
#
# 4.  **Measurement:**
#
#     *   When you measure a qubit, its superposition collapses, and it becomes either a 0 or a 1.
#     *   **Probabilistic Outcome:** The outcome of the measurement is probabilistic, determined by the probabilities encoded in the qubit's quantum state.
#     *   **Destructive:**  Measurement is a destructive process; it destroys the superposition.
#
# **How Quantum Computers Work (Simplified):**
#
# 1.  **Initialization:** Qubits are initialized to a known state (usually all 0s).
# 2.  **Quantum Algorithm:** A sequence of quantum gates is applied to the qubits to manipulate their states and create superpositions and entanglement. This is where the computation happens.
# 3.  **Measurement:** The qubits are measured, collapsing their superpositions into classical 0s and 1s.
# 4.  **Interpretation:** The measurement results are interpreted to obtain the solution to the problem.  Since the measurement is probabilistic, the algorithm may need to be run multiple times to get a reliable answer.
#
# **Types of Quantum Computers:**
#
# There are different physical implementations of qubits:
#
# *   **Superconducting Qubits:** These use superconducting circuits to create qubits.  They are currently the most advanced and widely used type.  Companies like Google, IBM, and Rigetti are working on superconducting quantum computers.
# *   **Trapped Ion Qubits:** These use individual ions (charged atoms) trapped in electromagnetic fields as qubits. They offer high fidelity and long coherence times.  Companies like IonQ and Quantinuum are developing trapped ion quantum computers.
# *   **Photonic Qubits:** These use photons (particles of light) as qubits.  They are promising for quantum communication and certain types of computation.
# *   **Neutral Atom Qubits:** These use neutral atoms trapped in optical lattices as qubits.  They offer scalability and long coherence times.
# *   **Topological Qubits:** These are theoretical qubits that are more resistant to noise.  Microsoft is pursuing this approach.
#
# **Challenges of Quantum Computing:**
#
# Quantum computing is still in its early stages of development.  There are several significant challenges:
#
# *   **Decoherence:** Qubits are very sensitive to their environment.  Any interaction with the outside world can cause them to lose their quantum properties (superposition and entanglement), leading to errors. Maintaining coherence for long enough to perform meaningful computations is a major hurdle.
# *   **Scalability:** Building quantum computers with a large number of qubits is technically difficult.  More qubits are needed to solve complex problems.
# *   **Error Correction:** Quantum computers are prone to errors.  Developing robust error correction techniques is essential for reliable computation.
# *   **Programming:**  Quantum algorithms are very different from classical algorithms.  Developing new quantum algorithms and programming languages is a challenge.
# *   **Cost:** Building and maintaining quantum computers is very expensive.
#
# **Potential Applications:**
#
# Despite the challenges, quantum computing has the potential to revolutionize many fields:
#
# *   **Drug Discovery and Materials Science:** Simulating molecules to design new drugs and materials with specific properties.
# *   **Financial Modeling:** Optimizing investment strategies, managing risk, and detecting fraud.
# *   **Logistics and Optimization:** Optimizing supply chains, routing traffic, and scheduling resources.
# *   **Artificial Intelligence:** Developing new machine learning algorithms and improving existing ones.
# *   **Cryptography:** Breaking existing encryption algorithms and developing new, quantum-resistant ones.
#
# **In Summary:**
#
# Quantum computing is a revolutionary technology that leverages the principles of quantum mechanics to solve complex problems. It's based on qubits, superposition, entanglement, and quantum gates. While still in its early stages, it has the potential to transform many fields.  The challenges are significant, but the potential rewards are enormous.
#
# Think of it this way:  Classical computing is like using an abacus; quantum computing is like having a magical calculator that can explore all possible solutions simultaneously.  We're not quite there yet with the magical calculator, but scientists and engineers are working hard to make it a reality.
#
# Q: Why is the sky blue?
# A: The sky is blue due to a phenomenon called **Rayleigh scattering**. Here's a breakdown of why:
#
# *   **Sunlight and its Colors:** Sunlight is actually made up of all the colors of the rainbow.
#
# *   **Entering the Atmosphere:** When sunlight enters the Earth's atmosphere, it collides with tiny air molecules (mostly nitrogen and oxygen).
#
# *   **Scattering of Light:** This collision causes the sunlight to scatter in different directions.
#
# *   **Rayleigh Scattering and Wavelength:** Rayleigh scattering is more effective at scattering shorter wavelengths of light. Blue and violet light have shorter wavelengths than other colors like red and orange.
#
# *   **Why Blue, Not Violet?** While violet light is scattered even *more* than blue light, there are a few reasons why we see a blue sky:
#
#     *   The sun emits slightly less violet light than blue light.
#     *   Our eyes are more sensitive to blue than violet.
#     *   The atmosphere absorbs some of the violet light.
#
# *   **The Result:** Because blue light is scattered more effectively, it spreads out across the sky, making the sky appear blue to our eyes.
#
# **Think of it like this:** Imagine throwing a bunch of small balls (blue light) and larger balls (red light) at a field of obstacles (air molecules). The small balls are more likely to bounce off the obstacles in different directions, while the larger balls are more likely to go straight through.
#
# **What about sunsets?**
#
# At sunset (or sunrise), the sun's light has to travel through much more of the atmosphere to reach our eyes. This means that most of the blue light has already been scattered away, leaving the longer wavelengths like orange and red to dominate the sky. This is why sunsets and sunrises often appear reddish or orange.
#
# Q: How does a rocket work?
# A: A rocket works by applying **Newton's Third Law of Motion: For every action, there is an equal and opposite reaction.**  Here's a breakdown:
#
# **1. The Core Principle: Expelling Mass for Thrust**
#
# *   Rockets don't "push off" against the ground or the atmosphere. They work even in the vacuum of space.
# *   They generate thrust by rapidly expelling mass (usually hot gas) out of their engine nozzle.  This is the "action."
# *   The "reaction" is the rocket accelerating in the opposite direction.
#
# **2. The Engine: Creating the Hot Gas**
#
# *   **Fuel and Oxidizer:**  Rockets typically carry both fuel and an oxidizer. The oxidizer provides the oxygen needed for combustion, especially vital in space where there's no atmosphere. Common combinations include:
#     *   **Liquid fuels and liquid oxidizers:**  Kerosene (RP-1) and liquid oxygen (LOX), or liquid hydrogen and liquid oxygen. These offer high performance but require complex storage and handling.
#     *   **Solid propellants:**  A mixture of a solid fuel and a solid oxidizer, pre-mixed into a solid "grain."  These are simpler and easier to store, but less controllable.
#     *   **Hybrid propellants:** A solid fuel and a liquid or gaseous oxidizer.  These offer a compromise between the two.
#
# *   **Combustion Chamber:** The fuel and oxidizer are injected into a combustion chamber where they mix and ignite. This creates extremely hot, high-pressure gas.
#
# *   **Nozzle:** The hot, high-pressure gas is then forced through a specially shaped nozzle. The nozzle does two important things:
#     *   **Accelerates the Gas:** The converging section of the nozzle forces the gas to accelerate.
#     *   **Directs the Flow:** The diverging section of the nozzle allows the gas to expand and further accelerate, directing it into a focused stream. This focused stream is what creates the thrust.
#
# **3.  Key Factors Affecting Thrust:**
#
# *   **Mass Flow Rate:** The amount of propellant (fuel and oxidizer) expelled per unit of time.  The more mass expelled, the greater the thrust.
# *   **Exhaust Velocity:** The speed at which the exhaust gas leaves the nozzle.  The faster the exhaust, the greater the thrust.  The design of the nozzle is crucial for maximizing exhaust velocity.
#
# **4.  How it Works in Space**
#
# *   In space, there's no air resistance to overcome, which is a major advantage.
# *   The rocket continues to accelerate as long as the engine is firing and expelling mass.
# *   Steering is achieved through various methods:
#     *   **Gimbaling the Engine:** Tilting the entire engine to change the direction of the thrust.
#     *   **Vernier Thrusters:** Small auxiliary rockets used for fine adjustments to the rocket's orientation.
#     *   **Reaction Control System (RCS):** Small thrusters placed around the rocket that fire in short bursts to control its rotation and attitude.
#     *   **Nozzle vanes:** Small vanes placed within the nozzle that can be adjusted to deflect the exhaust stream.
#
# **5.  Stages**
#
# *   Most rockets are multi-staged. This means they have multiple sections, each with its own engine and propellant.
# *   As each stage burns out its fuel, it is jettisoned, reducing the overall mass of the rocket. This makes the remaining stages more efficient in accelerating to higher speeds.
#
# **In summary, a rocket works by converting the chemical energy of its propellants into kinetic energy in the form of a high-speed exhaust jet. This exhaust is expelled out the back, and the rocket accelerates forward due to Newton's Third Law.**
#
# Q: Define reinforcement learning.
# A: Reinforcement learning (RL) is a type of machine learning where an **agent learns to make decisions in an environment to maximize a cumulative reward.**  It's learning through trial and error, where the agent interacts with the environment, observes the consequences of its actions (rewards or penalties), and adjusts its strategy to improve its performance over time.
#
# Here's a breakdown of the key components:
#
# *   **Agent:** The learner and decision-maker. It takes actions in the environment.
# *   **Environment:** The world the agent interacts with. It can be a simulated environment (like a game) or a real-world environment (like a robot navigating a room).
# *   **Action:** A choice the agent makes at each step in the environment.
# *   **State:** The current situation of the environment as perceived by the agent.  It's the agent's representation of the environment at a given time.
# *   **Reward:** A scalar value that the agent receives from the environment after taking an action.  Positive rewards encourage the agent to repeat the action, while negative rewards (penalties) discourage it.
# *   **Policy:** The agent's strategy for choosing actions based on the current state.  It's a mapping from states to actions.  The goal of RL is to learn an optimal policy.
# *   **Value Function:** An estimate of the expected cumulative reward the agent will receive starting from a particular state and following a particular policy. It helps the agent evaluate the long-term consequences of its actions.
#
# **In simpler terms:**
#
# Imagine training a dog. The dog (agent) performs an action (sit, stay, fetch). If the action is desirable (dog sits when told), you give the dog a treat (reward). If the action is undesirable (dog barks loudly), you might give a verbal correction (penalty). Over time, the dog learns which actions lead to rewards and which lead to penalties, and it adjusts its behavior accordingly.
#
# **Key Characteristics of Reinforcement Learning:**
#
# *   **Learning from Interaction:** RL agents learn through direct interaction with the environment.
# *   **Delayed Reward:** The agent might not receive immediate feedback for its actions. The consequences might be delayed.
# *   **Exploration vs. Exploitation:** The agent needs to balance exploring the environment to discover new actions and exploiting the knowledge it already has to maximize its rewards.
# *   **Trial and Error:** The agent learns through trial and error, trying different actions and observing the outcomes.
# *   **No Supervision:** Unlike supervised learning, RL agents are not provided with labeled data. They learn from the rewards they receive.
#
# **Examples of Reinforcement Learning Applications:**
#
# *   **Game playing:** Training AI to play games like Go, chess, and Atari games.
# *   **Robotics:** Controlling robots to perform tasks like navigation, manipulation, and assembly.
# *   **Resource management:** Optimizing the allocation of resources like energy, bandwidth, and advertising budget.
# *   **Recommendation systems:** Personalizing recommendations for users based on their past behavior.
# *   **Autonomous driving:** Training self-driving cars to navigate roads and avoid obstacles.
#
# In summary, reinforcement learning is about training an agent to make optimal decisions in an environment by learning from rewards and penalties received through trial and error. The goal is to develop a policy that maximizes the cumulative reward over time.

# %%
import time
questions = [
        "What is AI?",
        "Explain quantum computing.",
        "Why is the sky blue?",
        "How does a rocket work?",
        "Define reinforcement learning."
    ]
start = time.time()
for q in questions:
    res=model.invoke(q).content
end= time.time()

print(f"\nTime taken (sequential): {end - start} seconds")
# Out:
# Time taken (sequential): 30.508099794387817 seconds
